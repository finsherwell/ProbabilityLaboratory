# %% [markdown]
# # Combinatorics

# %% [markdown]
# Combinatorics is an area of mathematics primarily concerned with counting, both as a means and as an end to obtaining results, and certain properties of finite structures. (Source: Wikipedia)

# %% [markdown]
# This notebook takes ideas from Chapter 1 of David Morin's book, "Probability: For the Enthusiastic Beginner". These ideas will be explained, and then implemented computationally. This is to help myself and anyone else curious in probability to understand topics from a programming standpoint.

# %% [markdown]
# ### Factorials

# %% [markdown]
# ### Permutations

# %% [markdown]
# ### Ordered Sets

# %% [markdown]
# ### Unordered Sets

# %% [markdown]
# ### Binomial Coefficients

# %% [markdown]
# ### Summary
